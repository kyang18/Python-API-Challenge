# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-dcf81b45c1fe> in <module>
#       8
#       9 # Import API key
# ---> 10 from api_keys import weather_api_key
#      11
#      12 # Incorporated citipy to determine city based on latitude and longitude
#
# ImportError: cannot import name 'weather_api_key' from 'api_keys' (/Users/yangkaixin/Desktop/BootCamp/06-Python-APIs/Python-API-Challenge-HW6/WeatherPy/api_keys.py)

# %%
#Generate Cities List---------------------------------------------------

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
#Lists and counters
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lats_list = []
lngs_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %%
#Perform API Calls-------------------------------------------

# %%
print("Beginning Data Retrieval ")
print("-------------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#For loop matching city names with city_list
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lats_list.append(response["coord"]["lat"])
        lngs_list.append(response["coord"]["lon"])
        temp_max_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
        
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}")
        
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 : rikitea
# Processing Record 2 of Set 1 : ola
# Processing Record 3 of Set 1 : butaritari
# Processing Record 4 of Set 1 : sovetskiy
# Processing Record 5 of Set 1 : ushuaia
# Processing Record 6 of Set 1 : nchelenge
# Processing Record 7 of Set 1 : new norfolk
# Processing Record 8 of Set 1 : albany
# Processing Record 9 of Set 1 : jamestown
# Processing Record 10 of Set 1 : hermanus
# Processing Record 11 of Set 1 : kaitangata
# Processing Record 12 of Set 1 : geraldton
# Processing Record 13 of Set 1 : severo-kurilsk
# City not found. Skipping...
# Processing Record 14 of Set 1 : busselton
# Processing Record 15 of Set 1 : saint-leu
# Processing Record 16 of Set 1 : mar del plata
# Processing Record 17 of Set 1 : cayenne
# Processing Record 18 of Set 1 : provideniya
# Processing Record 19 of Set 1 : barrow
# Processing Record 20 of Set 1 : grindavik
# Processing Record 21 of Set 1 : qaanaaq
# Processing Record 22 of Set 1 : chokurdakh
# Processing Record 23 of Set 1 : bondo
# Processing Record 24 of Set 1 : vaini
# Processing Record 25 of Set 1 : gawler
# City not found. Skipping...
# Processing Record 26 of Set 1 : shelburne
# Processing Record 27 of Set 1 : birao
# Processing Record 28 of Set 1 : mataura
# Processing Record 29 of Set 1 : kantilo
# City not found. Skipping...
# Processing Record 30 of Set 1 : coffs harbour
# Processing Record 31 of Set 1 : mehamn
# Processing Record 32 of Set 1 : olinda
# Processing Record 33 of Set 1 : hobart
# Processing Record 34 of Set 1 : alihe
# Processing Record 35 of Set 1 : sobolevo
# Processing Record 36 of Set 1 : dikson
# Processing Record 37 of Set 1 : hambantota
# Processing Record 38 of Set 1 : atuona
# Processing Record 39 of Set 1 : tessalit
# Processing Record 40 of Set 1 : abalak
# Processing Record 41 of Set 1 : bredasdorp
# Processing Record 42 of Set 1 : puerto ayora
# Processing Record 43 of Set 1 : cabo san lucas
# Processing Record 44 of Set 1 : bluff
# Processing Record 45 of Set 1 : svetlyy
# Processing Record 46 of Set 1 : touros
# Processing Record 47 of Set 1 : ilulissat
# Processing Record 48 of Set 1 : tamorong
# Processing Record 49 of Set 1 : jesenice
# Processing Record 50 of Set 1 : rawson
# Processing Record 0 of Set 2 : kodiak
# Processing Record 1 of Set 2 : kapaa
# Processing Record 2 of Set 2 : punta arenas
# Processing Record 3 of Set 2 : saint-pierre
# Processing Record 4 of Set 2 : porto seguro
# Processing Record 5 of Set 2 : alexandria
# Processing Record 6 of Set 2 : leningradskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 : saint-louis
# Processing Record 8 of Set 2 : tocopilla
# Processing Record 9 of Set 2 : avera
# Processing Record 10 of Set 2 : narsaq
# City not found. Skipping...
# Processing Record 11 of Set 2 : shimoda
# Processing Record 12 of Set 2 : necochea
# Processing Record 13 of Set 2 : torbay
# Processing Record 14 of Set 2 : nome
# Processing Record 15 of Set 2 : east london
# Processing Record 16 of Set 2 : faanui
# Processing Record 17 of Set 2 : laguna
# City not found. Skipping...
# Processing Record 18 of Set 2 : iqaluit
# City not found. Skipping...
# Processing Record 19 of Set 2 : nishihara
# Processing Record 20 of Set 2 : visby
# Processing Record 21 of Set 2 : onega
# Processing Record 22 of Set 2 : palanga
# Processing Record 23 of Set 2 : bella vista
# Processing Record 24 of Set 2 : whitehorse
# Processing Record 25 of Set 2 : boulder city
# City not found. Skipping...
# Processing Record 26 of Set 2 : ribeira grande
# Processing Record 27 of Set 2 : baykit
# Processing Record 28 of Set 2 : upernavik
# Processing Record 29 of Set 2 : winneba
# Processing Record 30 of Set 2 : rio grande
# Processing Record 31 of Set 2 : fort nelson
# Processing Record 32 of Set 2 : kidal
# Processing Record 33 of Set 2 : kalanguy
# Processing Record 34 of Set 2 : henties bay
# Processing Record 35 of Set 2 : saskylakh
# Processing Record 36 of Set 2 : coquimbo
# Processing Record 37 of Set 2 : neuquen
# Processing Record 38 of Set 2 : bochil
# Processing Record 39 of Set 2 : port alfred
# Processing Record 40 of Set 2 : bethel
# Processing Record 41 of Set 2 : sibolga
# Processing Record 42 of Set 2 : tiksi
# Processing Record 43 of Set 2 : waikuku
# Processing Record 44 of Set 2 : bac lieu
# Processing Record 45 of Set 2 : kiama
# Processing Record 46 of Set 2 : fortuna
# Processing Record 47 of Set 2 : nisia floresta
# Processing Record 48 of Set 2 : lenauheim
# Processing Record 49 of Set 2 : namibe
# Processing Record 50 of Set 2 : yellowknife
# Processing Record 0 of Set 3 : sorada
# Processing Record 1 of Set 3 : champerico
# Processing Record 2 of Set 3 : djenne
# Processing Record 3 of Set 3 : lulea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 3 : dingle
# Processing Record 5 of Set 3 : port keats
# Processing Record 6 of Set 3 : svetlaya
# Processing Record 7 of Set 3 : port elizabeth
# Processing Record 8 of Set 3 : san francisco
# Processing Record 9 of Set 3 : portland
# Processing Record 10 of Set 3 : walvis bay
# Processing Record 11 of Set 3 : aklavik
# Processing Record 12 of Set 3 : inta
# Processing Record 13 of Set 3 : kavieng
# Processing Record 14 of Set 3 : clyde river
# City not found. Skipping...
# Processing Record 15 of Set 3 : arraial do cabo
# Processing Record 16 of Set 3 : salalah
# Processing Record 17 of Set 3 : idritsa
# Processing Record 18 of Set 3 : thompson
# Processing Record 36 of Set 4 : yulara
# Processing Record 37 of Set 4 : esperance
# Processing Record 38 of Set 4 : katyuzhanka
# Processing Record 39 of Set 4 : russell
# Processing Record 40 of Set 4 : mahebourg
# Processing Record 41 of Set 4 : hofn
# Processing Record 42 of Set 4 : havre-saint-pierre
# Processing Record 43 of Set 4 : el sauzal
# Processing Record 44 of Set 4 : norman wells
# Processing Record 45 of Set 4 : pitiquito
# Processing Record 46 of Set 4 : san cristobal
# Processing Record 47 of Set 4 : vilyuysk
# Processing Record 48 of Set 4 : saint-philippe
# Processing Record 49 of Set 4 : santa marta
# Processing Record 50 of Set 4 : cape town
# Processing Record 0 of Set 5 : kilmallock
# City not found. Skipping...
# Processing Record 1 of Set 5 : bailen
# Processing Record 2 of Set 5 : guerrero negro
# Processing Record 3 of Set 5 : manokwari
# Processing Record 4 of Set 5 : kloulklubed
# Processing Record 5 of Set 5 : yakima
# Processing Record 6 of Set 5 : srednekolymsk
# Processing Record 7 of Set 5 : tasiilaq
# Processing Record 8 of Set 5 : flinders
# Processing Record 9 of Set 5 : pisco
# Processing Record 10 of Set 5 : dakar
# Processing Record 11 of Set 5 : ahipara
# Processing Record 12 of Set 5 : arman
# Processing Record 13 of Set 5 : airai
# Processing Record 14 of Set 5 : hilo
# Processing Record 15 of Set 5 : mackay
# Processing Record 16 of Set 5 : belaya gora
# City not found. Skipping...
# Processing Record 17 of Set 5 : poindimie
# Processing Record 18 of Set 5 : namatanai
# Processing Record 19 of Set 5 : byron bay
# Processing Record 20 of Set 5 : tura
# Processing Record 21 of Set 5 : nicoya
# City not found. Skipping...
# Processing Record 22 of Set 5 : gurupi
# Processing Record 23 of Set 5 : tautira
# Processing Record 24 of Set 5 : port blair
# Processing Record 25 of Set 5 : luderitz
# Processing Record 26 of Set 5 : prince rupert
# Processing Record 27 of Set 5 : billings
# Processing Record 28 of Set 5 : axim
# Processing Record 29 of Set 5 : pevek
# Processing Record 30 of Set 5 : kruisfontein
# Processing Record 31 of Set 5 : killarney
# Processing Record 32 of Set 5 : jinji
# Processing Record 33 of Set 5 : faxinal
# Processing Record 34 of Set 5 : brownwood
# Processing Record 35 of Set 5 : skibbereen
# City not found. Skipping...
# Processing Record 36 of Set 5 : ponta do sol
# Processing Record 37 of Set 5 : buala
# Processing Record 38 of Set 5 : idrinskoye
# Processing Record 39 of Set 5 : kansas city
# City not found. Skipping...
# Processing Record 40 of Set 5 : papetoai
# Processing Record 41 of Set 5 : malanje
# City not found. Skipping...
# Processing Record 42 of Set 5 : tuktoyaktuk
# Processing Record 43 of Set 5 : paoua
# Processing Record 44 of Set 5 : shakawe
# Processing Record 45 of Set 5 : kadaya
# Processing Record 46 of Set 5 : kolin
# Processing Record 47 of Set 5 : port hedland
# Processing Record 48 of Set 5 : port lincoln
# Processing Record 49 of Set 5 : darhan
# Processing Record 50 of Set 5 : te anau
# Processing Record 0 of Set 6 : amurzet
# Processing Record 1 of Set 6 : boa vista
# Processing Record 2 of Set 6 : komsomolskiy
# Processing Record 3 of Set 6 : fukue
# Processing Record 4 of Set 6 : lata
# Processing Record 5 of Set 6 : chuy
# Processing Record 6 of Set 6 : nuuk
# Processing Record 7 of Set 6 : san antonio del norte
# Processing Record 8 of Set 6 : coihaique
# Processing Record 9 of Set 6 : ucluelet
# Processing Record 10 of Set 6 : tarakan
# Processing Record 11 of Set 6 : bambous virieux
# Processing Record 12 of Set 6 : cotonou
# Processing Record 13 of Set 6 : hirara
# Processing Record 14 of Set 6 : labuan
# Processing Record 15 of Set 6 : dudinka
# City not found. Skipping...
# Processing Record 16 of Set 6 : meulaboh
# Processing Record 17 of Set 6 : paamiut
# Processing Record 18 of Set 6 : dalvik
# Processing Record 19 of Set 6 : harper
# Processing Record 20 of Set 6 : san quintin
# Processing Record 21 of Set 6 : nanortalik
# Processing Record 22 of Set 6 : porto novo
# Processing Record 23 of Set 6 : saldanha
# City not found. Skipping...
# Processing Record 24 of Set 6 : kushmurun
# Processing Record 25 of Set 6 : ixtapa
# Processing Record 26 of Set 6 : berlevag
# Processing Record 27 of Set 6 : half moon bay
# Processing Record 28 of Set 6 : yabelo
# Processing Record 29 of Set 6 : kayerkan
# Processing Record 30 of Set 6 : seoul
# Processing Record 31 of Set 6 : kavaratti
# Processing Record 32 of Set 6 : kotido
# Processing Record 33 of Set 6 : mitu
# Processing Record 34 of Set 6 : longyearbyen
# Processing Record 35 of Set 6 : voznesenye
# Processing Record 36 of Set 6 : carauari
# Processing Record 37 of Set 6 : morada nova
# Processing Record 38 of Set 6 : saint anthony
# Processing Record 39 of Set 6 : caravelas
# Processing Record 40 of Set 6 : adrar
# Processing Record 41 of Set 6 : bilma
# Processing Record 42 of Set 6 : kununurra
# Processing Record 43 of Set 6 : sambir
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 6 : hebi
# Processing Record 45 of Set 6 : trinidad
# Processing Record 46 of Set 6 : neyshabur
# Processing Record 47 of Set 6 : port macquarie
# Processing Record 48 of Set 6 : itarema
# Processing Record 49 of Set 6 : sahuaripa
# Processing Record 50 of Set 6 : shaki
# Processing Record 0 of Set 7 : karak
# Processing Record 1 of Set 7 : richards bay
# Processing Record 2 of Set 7 : megion
# Processing Record 3 of Set 7 : fairbanks
# Processing Record 4 of Set 7 : jalu
# City not found. Skipping...
# Processing Record 5 of Set 7 : peyima
# Processing Record 6 of Set 7 : flin flon
# City not found. Skipping...
# Processing Record 7 of Set 7 : pangai
# Processing Record 8 of Set 7 : mitsamiouli
# Processing Record 9 of Set 7 : bukama
# Processing Record 10 of Set 7 : tilichiki
# Processing Record 11 of Set 7 : manbij
# City not found. Skipping...
# Processing Record 12 of Set 7 : oranjemund
# Processing Record 13 of Set 7 : kungurtug
# Processing Record 14 of Set 7 : aksum
# Processing Record 15 of Set 7 : paita
# Processing Record 16 of Set 7 : oriximina
# Processing Record 17 of Set 7 : katsuura
# Processing Record 18 of Set 7 : great bend
# Processing Record 19 of Set 7 : vangaindrano
# Processing Record 20 of Set 7 : sorong
# Processing Record 21 of Set 7 : price
# City not found. Skipping...
# Processing Record 22 of Set 7 : praia
# Processing Record 23 of Set 7 : hasaki
# Processing Record 24 of Set 7 : cidreira
# Processing Record 25 of Set 7 : kralendijk
# Processing Record 26 of Set 7 : ibra
# Processing Record 27 of Set 7 : shingu
# Processing Record 28 of Set 7 : vestmannaeyjar
# Processing Record 29 of Set 7 : mafinga
# City not found. Skipping...
# Processing Record 30 of Set 7 : erenhot
# Processing Record 31 of Set 7 : padang
# Processing Record 32 of Set 7 : kurchum
# Processing Record 33 of Set 7 : singaparna
# City not found. Skipping...
# Processing Record 34 of Set 7 : la ronge
# Processing Record 35 of Set 7 : sesheke
# City not found. Skipping...
# Processing Record 36 of Set 7 : saint-augustin
# Processing Record 37 of Set 7 : odweyne
# Processing Record 38 of Set 7 : cullera
# Processing Record 39 of Set 7 : cabedelo
# Processing Record 40 of Set 7 : santa maria
# Processing Record 41 of Set 7 : sao felix do xingu
# Processing Record 42 of Set 7 : verkhnyaya inta
# Processing Record 43 of Set 7 : denekamp
# Processing Record 44 of Set 7 : luba
# Processing Record 45 of Set 7 : mecca
# Processing Record 46 of Set 7 : salihorsk
# Processing Record 47 of Set 7 : searcy
# Processing Record 48 of Set 7 : chimore
# Processing Record 49 of Set 7 : viedma
# Processing Record 50 of Set 7 : salta
# Processing Record 0 of Set 8 : alpena
# Processing Record 1 of Set 8 : xai-xai
# Processing Record 2 of Set 8 : guiratinga
# Processing Record 3 of Set 8 : acapulco
# Processing Record 4 of Set 8 : medvezhyegorsk
# Processing Record 5 of Set 8 : aswan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 8 : gazanjyk
# Processing Record 7 of Set 8 : dabat
# Processing Record 8 of Set 8 : cascais
# Processing Record 9 of Set 8 : mentougou
# Processing Record 10 of Set 8 : gao
# Processing Record 11 of Set 8 : linxia
# Processing Record 12 of Set 8 : deputatskiy
# Processing Record 13 of Set 8 : panaba
# Processing Record 14 of Set 8 : malakal
# Processing Record 15 of Set 8 : kirakira
# Processing Record 16 of Set 8 : novaya ladoga
# City not found. Skipping...
# Processing Record 17 of Set 8 : vila velha
# Processing Record 18 of Set 8 : kalaleh
# Processing Record 19 of Set 8 : sabaudia
# Processing Record 20 of Set 8 : lompoc
# Processing Record 21 of Set 8 : egvekinot
# Processing Record 22 of Set 8 : valday
# Processing Record 23 of Set 8 : temirtau
# Processing Record 24 of Set 8 : kerman
# Processing Record 25 of Set 8 : makarov
# Processing Record 26 of Set 8 : haines junction
# Processing Record 27 of Set 8 : khorixas
# Processing Record 28 of Set 8 : saint george
# Processing Record 29 of Set 8 : glace bay
# City not found. Skipping...
# Processing Record 30 of Set 8 : bosaso
# Processing Record 31 of Set 8 : los llanos de aridane
# Processing Record 32 of Set 8 : parnarama
# Processing Record 33 of Set 8 : san andres
# Processing Record 34 of Set 8 : klaksvik
# Processing Record 35 of Set 8 : amga
# Processing Record 36 of Set 8 : belmonte
# Processing Record 3 of Set 10 : broome
# Processing Record 4 of Set 10 : hervey bay
# Processing Record 5 of Set 10 : miracema do tocantins
# Processing Record 6 of Set 10 : arkhangelsk
# Processing Record 7 of Set 10 : marawi
# Processing Record 8 of Set 10 : shenjiamen
# Processing Record 9 of Set 10 : yasothon
# Processing Record 10 of Set 10 : ahuimanu
# Processing Record 11 of Set 10 : kathmandu
# Processing Record 12 of Set 10 : husavik
# Processing Record 13 of Set 10 : roma
# Processing Record 14 of Set 10 : ligaya
# Processing Record 15 of Set 10 : celestun
# Processing Record 16 of Set 10 : ullapool
# Processing Record 17 of Set 10 : salinas
# Processing Record 18 of Set 10 : hay river
# Processing Record 19 of Set 10 : muros
# Processing Record 20 of Set 10 : ninh binh
# Processing Record 21 of Set 10 : kovdor
# Processing Record 22 of Set 10 : kuusamo
# Processing Record 23 of Set 10 : saint austell
# Processing Record 24 of Set 10 : bariadi
# Processing Record 25 of Set 10 : arti
# Processing Record 26 of Set 10 : karatsu
# Processing Record 27 of Set 10 : maun
# Processing Record 28 of Set 10 : biak
# Processing Record 29 of Set 10 : atambua
# Processing Record 30 of Set 10 : baoqing
# Processing Record 31 of Set 10 : ossora
# Processing Record 32 of Set 10 : calvinia
# City not found. Skipping...
# Processing Record 33 of Set 10 : houston
# Processing Record 34 of Set 10 : along
# Processing Record 35 of Set 10 : carutapera
# Processing Record 36 of Set 10 : pangnirtung
# Processing Record 37 of Set 10 : jinka
# Processing Record 38 of Set 10 : pavlohrad
# Processing Record 39 of Set 10 : queanbeyan
# Processing Record 40 of Set 10 : labuhan
# Processing Record 41 of Set 10 : sao filipe
# City not found. Skipping...
# Processing Record 42 of Set 10 : alyangula
# Processing Record 43 of Set 10 : non thai
# Processing Record 44 of Set 10 : beya
# Processing Record 45 of Set 10 : kupang
# Processing Record 46 of Set 10 : olafsvik
# Processing Record 47 of Set 10 : pochutla
# City not found. Skipping...
# Processing Record 48 of Set 10 : esna
# Processing Record 49 of Set 10 : dubti
# Processing Record 50 of Set 10 : saint-georges
# Processing Record 0 of Set 11 : skiathos
# Processing Record 1 of Set 11 : tomball
# Processing Record 2 of Set 11 : tabuk
# Processing Record 3 of Set 11 : angol
# Processing Record 4 of Set 11 : san angelo
# Processing Record 5 of Set 11 : soyo
# Processing Record 6 of Set 11 : vilhena
# Processing Record 7 of Set 11 : sechura
# Processing Record 8 of Set 11 : galle
# Processing Record 9 of Set 11 : lasa
# Processing Record 10 of Set 11 : kopavogur
# Processing Record 11 of Set 11 : beloha
# Processing Record 12 of Set 11 : north battleford
# Processing Record 13 of Set 11 : grand gaube
# Processing Record 14 of Set 11 : northam
# Processing Record 15 of Set 11 : riacho de santana
# Processing Record 16 of Set 11 : ponnani
# Processing Record 17 of Set 11 : coromandel
# Processing Record 18 of Set 11 : canon city
# Processing Record 19 of Set 11 : lavrentiya
# Processing Record 20 of Set 11 : honiara
# Processing Record 21 of Set 11 : coahuayana
# Processing Record 22 of Set 11 : ginda
# Processing Record 23 of Set 11 : ladario
# Processing Record 24 of Set 11 : faya
# Processing Record 25 of Set 11 : abnub
# Processing Record 26 of Set 11 : hamilton
# Processing Record 27 of Set 11 : evensk
# Processing Record 28 of Set 11 : tammisaari
# Processing Record 29 of Set 11 : dzidzantun
# Processing Record 30 of Set 11 : saint-joseph
# Processing Record 31 of Set 11 : chardara
# Processing Record 32 of Set 11 : vao
# Processing Record 33 of Set 11 : trairi
# Processing Record 34 of Set 11 : sakaiminato
# Processing Record 35 of Set 11 : westport
# Processing Record 36 of Set 11 : halifax
# Processing Record 37 of Set 11 : peniche
# Processing Record 38 of Set 11 : mangrol
# Processing Record 39 of Set 11 : antalaha
# Processing Record 40 of Set 11 : kachug
# City not found. Skipping...
# Processing Record 41 of Set 11 : pryazha
# City not found. Skipping...
# Processing Record 42 of Set 11 : evanston
# Processing Record 43 of Set 11 : luganville
# Processing Record 44 of Set 11 : yeppoon
# Processing Record 45 of Set 11 : umm kaddadah
# Processing Record 46 of Set 11 : bako
# Processing Record 47 of Set 11 : paraiso
# City not found. Skipping...
# Processing Record 48 of Set 11 : gigmoto
# Processing Record 49 of Set 11 : abrau-dyurso
# Processing Record 50 of Set 11 : scarborough
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
#Convert Raw Data to DataFrame---------------------------------------

# %%
#Create a dataframe using information from data retrieval
weather_data = pd.DataFrame({
    "City" : city_list,
    "Lat" : lats_list,
    "Lng" : lngs_list,
    "Max Temp" : temp_max_list,
    "Humidity" : humidity_list,
    "Clouds" : cloud_list,
    "Wind Speed" : wind_speed_list,
    "Country" : country_list,
    "Date" : date_list    
})

# %%
#Count weather data
weather_data.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Clouds        560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
#Display dataframe
weather_data.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Clouds  Wind Speed Country  \
# 0     Rikitea -23.12 -134.97     75.63        84      69       16.98      PF
# 1         Ola  59.58  151.28     49.80        85     100        7.38      RU
# 2  Butaritari   3.07  172.79     83.30        69      37        9.55      KI
# 3   Sovetskiy  61.36   63.58     50.70        49       3        9.60      RU
# 4     Ushuaia -54.80  -68.30     33.80        86      20        4.70      AR
#
#          Date
# 0  1592453165
# 1  1592453577
# 2  1592453254
# 3  1592453281
# 4  1592453256

# %%
#Save weather data to a cities csv file
weather_data.to_csv("output_data/cities.csv", index=False)

# %%
#Plotting the Data------------------------------------------------

# %%
# Latitude vs. Temperature Plot-----------------------------------

# %%
#Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Max Temperature (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %%
#Latitude vs. Humidity Plot----------------------------------------

# %%
#Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Humidity"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Images/City Latitude vs Humidity.png")

# %%
# Latitude vs. Cloudiness Plot----------------------------------

# %%
#Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Clouds"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Cloudiness (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %%
# Latitude vs. Wind Speed Plot------------------------------------

# %%
#Latitude vs. Wind Speed Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%))")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Images/City Latitude vs Wind Speed.png")
